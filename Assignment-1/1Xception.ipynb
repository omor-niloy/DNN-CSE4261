# %%
import keras
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from keras import layers

import numpy as np
# Out:
# 2025-06-22 15:49:05.910563: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-06-22 15:49:05.926095: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-06-22 15:49:05.930696: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-22 15:49:05.941914: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
#Load dataset
(x_train_tmp, y_train_tmp), (x_test_tmp, y_test_tmp) = keras.datasets.cifar100.load_data()
# print(y_train_tmp.shape)
x_train = []
y_train = []
x_test = []
y_test = []
for i in range (y_train_tmp.shape[0]):
    if (0 <= y_train_tmp[i][0] <= 19):
        x_train.append(x_train_tmp[i])
        y_train.append(y_train_tmp[i])
for i in range (y_test_tmp.shape[0]):
    if (0 <= y_test_tmp[i][0] <= 19):
        x_test.append(x_test_tmp[i])
        y_test.append(y_test_tmp[i])
x_train = np.array(x_train)
y_train = np.array(y_train)
x_test = np.array(x_test)
y_test = np.array(y_test)

x_train = x_train / 255.0
x_test = x_test / 255.0


trainY = to_categorical(y_train, num_classes = 20)
testY = to_categorical(y_test, num_classes = 20)

# %%
xception_model = keras.applications.Xception(
    include_top=False,
    weights="imagenet",
    input_tensor=None,
    input_shape=None,
    pooling=None,
)

# xception_model.summary()

model = keras.Sequential(
    [
        keras.Input(shape=(32, 32, 3)),
        xception_model,

        layers.Flatten(),

        layers.Dropout(0.4),
        layers.Dense(512),
        layers.BatchNormalization(),
        layers.Activation("relu"),
        
        layers.Dropout(0.4),
        layers.Dense(256),
        layers.BatchNormalization(),
        layers.Activation("relu"),

        layers.Dense(20, activation='softmax')
    ]
)
model.summary()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1750585750.754399   18838 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1750585751.239039   18838 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1750585751.239222   18838 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1750585751.240335   18838 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1750585751.240497   18838 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1750585751.240625   18838 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1750585751.298033   18838 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1750585751.298262   18838 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-06-22 15:49:11.298351: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# I0000 00:00:1750585751.298419   18838 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-06-22 15:49:11.298519: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7230 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1070, pci bus id: 0000:01:00.0, compute capability: 6.1
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ xception (Functional)           │ (None, 1, 1, 2048)     │    20,861,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     1,049,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 20)             │         5,140 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 22,050,108 (84.11 MB)
#  Trainable params: 21,994,044 (83.90 MB)
#  Non-trainable params: 56,064 (219.00 KB)

# %%
early_stopping = keras.callbacks.EarlyStopping(monitor="val_loss", patience=15, restore_best_weights=True)

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=5e-4),
    loss=keras.losses.CategoricalCrossentropy(from_logits=False),
    metrics=['accuracy'],
)

model.fit(x_train, trainY, epochs=5, callbacks=[early_stopping], batch_size=32, validation_split=0.1)
# Out:
# Epoch 1/5
# I0000 00:00:1750585766.921267   18875 service.cc:146] XLA service 0x78b86c003610 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1750585766.921287   18875 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce GTX 1070, Compute Capability 6.1
# 2025-06-22 15:49:27.343189: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-06-22 15:49:29.186290: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:524] Loaded runtime CuDNN library: 9.1.0 but source was compiled with: 9.3.0.  CuDNN library needs to have matching major version and equal or higher minor version. If using a binary install, upgrade your CuDNN library.  If building from sources, make sure the library loaded at runtime is compatible with the version specified during compile configuration.
# 2025-06-22 15:49:29.859889: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:524] Loaded runtime CuDNN library: 9.1.0 but source was compiled with: 9.3.0.  CuDNN library needs to have matching major version and equal or higher minor version. If using a binary install, upgrade your CuDNN library.  If building from sources, make sure the library loaded at runtime is compatible with the version specified during compile configuration.
# 2025-06-22 15:49:29.902138: W tensorflow/core/framework/op_kernel.cc:1840] OP_REQUIRES failed at xla_ops.cc:577 : FAILED_PRECONDITION: DNN library initialization failed. Look at the errors above for more details.
# 2025-06-22 15:49:29.902207: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: FAILED_PRECONDITION: DNN library initialization failed. Look at the errors above for more details.
# 	 [[{{node StatefulPartitionedCall}}]]
# ---------------------------------------------------------------------------
# FailedPreconditionError                   Traceback (most recent call last)
# Cell In[4], line 9
#       1 early_stopping = keras.callbacks.EarlyStopping(monitor="val_loss", patience=15, restore_best_weights=True)
#       3 model.compile(
#       4     optimizer=keras.optimizers.Adam(learning_rate=5e-4),
#       5     loss=keras.losses.CategoricalCrossentropy(from_logits=False),
#       6     metrics=['accuracy'],
#       7 )
# ----> 9 model.fit(x_train, trainY, epochs=5, callbacks=[early_stopping], batch_size=32, validation_split=0.1)
#
# File ~/miniforge3/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/miniforge3/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# FailedPreconditionError: Graph execution error:
#
# Detected at node StatefulPartitionedCall defined at (most recent call last):
#   File "/home/cse/miniforge3/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#
#   File "/home/cse/miniforge3/lib/python3.9/runpy.py", line 87, in _run_code
#
#   File "/home/cse/miniforge3/lib/python3.9/site-packages/ipykernel_launcher.py", line 18, in <module>
#
#   File "/home/cse/miniforge3/lib/python3.9/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#
#   File "/home/cse/miniforge3/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 739, in start
#
#   File "/home/cse/miniforge3/lib/python3.9/site-packages/tornado/platform/asyncio.py", line 211, in start
#
#   File "/home/cse/miniforge3/lib/python3.9/asyncio/base_events.py", line 601, in run_forever
#
#   File "/home/cse/miniforge3/lib/python3.9/asyncio/base_events.py", line 1905, in _run_once
#
#   File "/home/cse/miniforge3/lib/python3.9/asyncio/events.py", line 80, in _run
#
#   File "/home/cse/miniforge3/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#
#   File "/home/cse/miniforge3/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#
#   File "/home/cse/miniforge3/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#
#   File "/home/cse/miniforge3/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#
#   File "/home/cse/miniforge3/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#
#   File "/home/cse/miniforge3/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#
#   File "/home/cse/miniforge3/lib/python3.9/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#
#   File "/home/cse/miniforge3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3048, in run_cell
#
#   File "/home/cse/miniforge3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3103, in _run_cell
#
#   File "/home/cse/miniforge3/lib/python3.9/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#
#   File "/home/cse/miniforge3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3308, in run_cell_async
#
#   File "/home/cse/miniforge3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3490, in run_ast_nodes
#
#   File "/home/cse/miniforge3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3550, in run_code
#
#   File "/tmp/ipykernel_18838/1501944012.py", line 9, in <module>
#
#   File "/home/cse/miniforge3/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/home/cse/miniforge3/lib/python3.9/site-packages/keras/src/backend/tensorflow/trainer.py", line 377, in fit
#
#   File "/home/cse/miniforge3/lib/python3.9/site-packages/keras/src/backend/tensorflow/trainer.py", line 220, in function
#
#   File "/home/cse/miniforge3/lib/python3.9/site-packages/keras/src/backend/tensorflow/trainer.py", line 133, in multi_step_on_iterator
#
# DNN library initialization failed. Look at the errors above for more details.
# 	 [[{{node StatefulPartitionedCall}}]] [Op:__inference_multi_step_on_iterator_33895]

# %%
model.evaluate(x_test, testY)
# Out:
# 63/63 [==============================] - 4s 65ms/step - loss: 1.1585 - accuracy: 0.6425
# [1.1585408449172974, 0.6424999833106995]
