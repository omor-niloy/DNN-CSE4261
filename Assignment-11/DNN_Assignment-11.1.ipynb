# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import models, transforms
from torchvision.datasets import LFWPairs
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
import numpy as np
import random

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
import os
from torch.utils.data import Dataset
from PIL import Image

class LFWPairDataset(Dataset):
    def __init__(self, image_dir, pairs_file, transform=None):
        self.image_dir = image_dir
        self.transform = transform
        self.pairs = []

        with open(pairs_file, 'r') as f:
            lines = f.readlines()[1:]  # skip header line

            for line in lines:
                parts = line.strip().split()
                if len(parts) == 3:
                    name, idx1, idx2 = parts
                    img1 = os.path.join(image_dir, name, f"{name}_{int(idx1):04d}.jpg")
                    img2 = os.path.join(image_dir, name, f"{name}_{int(idx2):04d}.jpg")
                    self.pairs.append((img1, img2, 1))  # same
                elif len(parts) == 4:
                    name1, idx1, name2, idx2 = parts
                    img1 = os.path.join(image_dir, name1, f"{name1}_{int(idx1):04d}.jpg")
                    img2 = os.path.join(image_dir, name2, f"{name2}_{int(idx2):04d}.jpg")
                    self.pairs.append((img1, img2, 0))  # different

    def __len__(self):
        return len(self.pairs)

    def __getitem__(self, idx):
        img1_path, img2_path, label = self.pairs[idx]
        img1 = Image.open(img1_path).convert("RGB")
        img2 = Image.open(img2_path).convert("RGB")

        if self.transform:
            img1 = self.transform(img1)
            img2 = self.transform(img2)

        return img1, img2, label

# %%
from torchvision import transforms

transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor()
])

# Choose one of the following:
train_dataset = LFWPairDataset(
    image_dir="/home/cse/Documents/NP/datasets/LFW/lfw_funneled",
    pairs_file="/home/cse/Documents/NP/datasets/LFW/pairsDevTrain.txt",
    transform=transform
)

# or for full benchmark:
test_dataset = LFWPairDataset(
    image_dir="/home/cse/Documents/NP/datasets/LFW/lfw_funneled",
    pairs_file="/home/cse/Documents/NP/datasets/LFW/pairsDevTest.txt",
    transform=transform
)
print("Train set size:", len(train_dataset))
print("Test set size:", len(test_dataset))
# Out:
# Train set size: 2200
# Test set size: 1000

# %%
import matplotlib.pyplot as plt

def show_batch(dataset, n=5):
    plt.figure(figsize=(10, 4))
    for i in range(n):
        img1, img2, label = dataset[i]
        img1 = img1.permute(1, 2, 0).numpy()
        img2 = img2.permute(1, 2, 0).numpy()

        plt.subplot(2, n, i + 1)
        plt.imshow(img1)
        plt.axis('off')
        plt.title("Image")

        plt.subplot(2, n, n + i + 1)
        plt.imshow(img2)
        plt.axis('off')
        plt.title("True" if label == 1 else "False")

    plt.tight_layout()
    plt.show()

# Show some samples
# show_batch(train_dataset)
show_batch(test_dataset)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt

# ==== 1. Base Embedding Network ====
class FaceEmbeddingNet(nn.Module):
    def __init__(self):
        super(FaceEmbeddingNet, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(3, 32, 3, padding=1), nn.ReLU(), nn.MaxPool2d(2),
            nn.Conv2d(32, 64, 3, padding=1), nn.ReLU(), nn.MaxPool2d(2),
            nn.Conv2d(64, 128, 3, padding=1), nn.ReLU(), nn.AdaptiveAvgPool2d((1, 1))
        )
        self.fc = nn.Linear(128, 128)

    def forward(self, x):
        x = self.conv(x)
        x = x.view(x.size(0), -1)
        return self.fc(x)

# ==== 2. Siamese Network for BCE ====
class SiameseBCEModel(nn.Module):
    def __init__(self, embedding_net):
        super(SiameseBCEModel, self).__init__()
        self.embedding_net = embedding_net

    def forward(self, x1, x2):
        f1 = self.embedding_net(x1)
        f2 = self.embedding_net(x2)
        return F.cosine_similarity(f1, f2).unsqueeze(1)

# ==== 3. Contrastive Loss ====
class ContrastiveLoss(nn.Module):
    def __init__(self, margin=1.0):
        super(ContrastiveLoss, self).__init__()
        self.margin = margin

    def forward(self, output1, output2, label):
        dist = F.pairwise_distance(output1, output2)
        loss = label * dist.pow(2) + (1 - label) * F.relu(self.margin - dist).pow(2)
        return loss.mean()

# ==== 4. Triplet Loss Dataset Wrapping ====
class TripletDataset(torch.utils.data.Dataset):
    def __init__(self, dataset):
        self.dataset = dataset

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, index):
        anchor_img1, anchor_img2, label = self.dataset[index]
        if label == 1:
            positive = anchor_img2
            negative = self.dataset[(index + 1) % len(self.dataset)][1]
        else:
            positive = self.dataset[(index + 1) % len(self.dataset)][1]
            negative = anchor_img2
        return anchor_img1, positive, negative

# %%
def train_bce(model, dataloader, epochs=15):
    model.train()
    criterion = nn.BCELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
    losses = []
    for epoch in range(epochs):
        total_loss = 0
        for img1, img2, label in dataloader:
            img1, img2 = img1.to(device), img2.to(device)
            label = label.float().unsqueeze(1).to(device)
            pred = torch.sigmoid(model(img1, img2))
            loss = criterion(pred, label)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        avg_loss = total_loss / len(dataloader)
        losses.append(avg_loss)
        print(f"[BCE] Epoch {epoch+1}, Loss: {avg_loss:.4f}")
    return model, losses

def train_contrastive(embedding_net, dataloader, epochs=15):
    embedding_net.train()
    criterion = ContrastiveLoss()
    optimizer = torch.optim.Adam(embedding_net.parameters(), lr=1e-4)
    losses = []
    for epoch in range(epochs):
        total_loss = 0
        for img1, img2, label in dataloader:
            img1, img2 = img1.to(device), img2.to(device)
            label = label.float().to(device)
            out1 = embedding_net(img1)
            out2 = embedding_net(img2)
            loss = criterion(out1, out2, label)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        avg_loss = total_loss / len(dataloader)
        losses.append(avg_loss)
        print(f"[Contrastive] Epoch {epoch+1}, Loss: {avg_loss:.4f}")
    return embedding_net, losses

def train_triplet(embedding_net, dataloader, epochs=15):
    embedding_net.train()
    criterion = nn.TripletMarginLoss(margin=1.0)
    optimizer = torch.optim.Adam(embedding_net.parameters(), lr=1e-4)
    losses = []
    for epoch in range(epochs):
        total_loss = 0
        for anchor, positive, negative in dataloader:
            anchor = anchor.to(device)
            positive = positive.to(device)
            negative = negative.to(device)
            anchor_out = embedding_net(anchor)
            pos_out = embedding_net(positive)
            neg_out = embedding_net(negative)
            loss = criterion(anchor_out, pos_out, neg_out)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        avg_loss = total_loss / len(dataloader)
        losses.append(avg_loss)
        print(f"[Triplet] Epoch {epoch+1}, Loss: {avg_loss:.4f}")
    return embedding_net, losses

# %%
def show_verification(img1, img2, is_same, sim_score):
    fig, ax = plt.subplots(1, 2)
    ax[0].imshow(img1.permute(1, 2, 0))
    ax[0].set_title("Image 1")
    ax[1].imshow(img2.permute(1, 2, 0))
    ax[1].set_title(f"Image 2\nSim: {sim_score:.2f}")
    
    border_color = 'green' if is_same else 'red'
    for a in ax:
        a.axis('off')
        for spine in a.spines.values():
            spine.set_edgecolor(border_color)
            spine.set_linewidth(4)
    plt.show()

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Data loaders
data_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=True)
triplet_loader = DataLoader(TripletDataset(train_dataset), batch_size=32, shuffle=True)

# %%
bce_model = SiameseBCEModel(FaceEmbeddingNet().to(device))
bce_model, bce_losses = train_bce(bce_model, data_loader)
# Out:
# [BCE] Epoch 1, Loss: 0.7775
# [BCE] Epoch 2, Loss: 0.7383
# [BCE] Epoch 3, Loss: 0.7287
# [BCE] Epoch 4, Loss: 0.7265
# [BCE] Epoch 5, Loss: 0.7183
# [BCE] Epoch 6, Loss: 0.7137
# [BCE] Epoch 7, Loss: 0.7171
# [BCE] Epoch 8, Loss: 0.7118
# [BCE] Epoch 9, Loss: 0.7060
# [BCE] Epoch 10, Loss: 0.7052
# [BCE] Epoch 11, Loss: 0.7032
# [BCE] Epoch 12, Loss: 0.7035
# [BCE] Epoch 13, Loss: 0.7008
# [BCE] Epoch 14, Loss: 0.6957
# [BCE] Epoch 15, Loss: 0.6946

# %%
contrastive_net = FaceEmbeddingNet().to(device)
contrastive_net, contrastive_losses = train_contrastive(contrastive_net, data_loader)
# Out:
# [Contrastive] Epoch 1, Loss: 0.3287
# [Contrastive] Epoch 2, Loss: 0.2742
# [Contrastive] Epoch 3, Loss: 0.2718
# [Contrastive] Epoch 4, Loss: 0.2635
# [Contrastive] Epoch 5, Loss: 0.2564
# [Contrastive] Epoch 6, Loss: 0.2549
# [Contrastive] Epoch 7, Loss: 0.2534
# [Contrastive] Epoch 8, Loss: 0.2541
# [Contrastive] Epoch 9, Loss: 0.2533
# [Contrastive] Epoch 10, Loss: 0.2529
# [Contrastive] Epoch 11, Loss: 0.2512
# [Contrastive] Epoch 12, Loss: 0.2502
# [Contrastive] Epoch 13, Loss: 0.2479
# [Contrastive] Epoch 14, Loss: 0.2474
# [Contrastive] Epoch 15, Loss: 0.2478

# %%
triplet_net = FaceEmbeddingNet().to(device)
triplet_net, triplet_losses = train_triplet(triplet_net, triplet_loader)
# Out:
# [Triplet] Epoch 1, Loss: 0.9975
# [Triplet] Epoch 2, Loss: 0.9892
# [Triplet] Epoch 3, Loss: 0.9805
# [Triplet] Epoch 4, Loss: 0.9781
# [Triplet] Epoch 5, Loss: 0.9742
# [Triplet] Epoch 6, Loss: 0.9651
# [Triplet] Epoch 7, Loss: 0.9688
# [Triplet] Epoch 8, Loss: 0.9654
# [Triplet] Epoch 9, Loss: 0.9659
# [Triplet] Epoch 10, Loss: 0.9619
# [Triplet] Epoch 11, Loss: 0.9611
# [Triplet] Epoch 12, Loss: 0.9591
# [Triplet] Epoch 13, Loss: 0.9626
# [Triplet] Epoch 14, Loss: 0.9576
# [Triplet] Epoch 15, Loss: 0.9555

# %%
def plot_losses(bce, contrastive, triplet):
    plt.plot(bce, label="BCE Loss")
    plt.plot(contrastive, label="Contrastive Loss")
    plt.plot(triplet, label="Triplet Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.title("Loss Curves for Different Objectives")
    plt.legend()
    plt.grid()
    plt.show()

# %%
# ==== 9. Plot Comparison ====
plot_losses(bce_losses, contrastive_losses, triplet_losses)

# %%
import matplotlib.pyplot as plt

def show_verification_row(images, sims, decisions, titles):
    fig, axs = plt.subplots(2, len(images), figsize=(4 * len(images), 4))
    for i in range(len(images)):
        img1, img2 = images[i]
        is_same = decisions[i]
        sim_score = sims[i]
        title = titles[i]

        axs[0, i].imshow(img1.permute(1, 2, 0))
        axs[0, i].set_title(f"{title}\nImage 1")
        axs[0, i].axis('off')

        axs[1, i].imshow(img2.permute(1, 2, 0))
        axs[1, i].set_title(f"Image 2\nSim: {sim_score:.2f}")
        axs[1, i].axis('off')

        color = 'green' if is_same else 'red'
        for a in [axs[0, i], axs[1, i]]:
            for spine in a.spines.values():
                spine.set_edgecolor(color)
                spine.set_linewidth(3)
    plt.tight_layout()
    plt.show()


def evaluate_bce(model, dataset, dataloader, index=0, threshold=0.5):
    model.eval()
    correct, total = 0, 0
    with torch.no_grad():
        for img1, img2, label in dataloader:
            img1, img2, label = img1.to(device), img2.to(device), label.to(device)
            output = torch.sigmoid(model(img1, img2))
            preds = (output > threshold).float()
            correct += (preds.squeeze() == label).sum().item()
            total += label.size(0)
    acc = correct / total

    img1, img2, label = dataset[index]
    with torch.no_grad():
        sim = torch.sigmoid(model(img1.unsqueeze(0).to(device), img2.unsqueeze(0).to(device))).item()
    is_same = sim > threshold
    return acc, (img1, img2), sim, is_same


def evaluate_contrastive(model, dataset, dataloader, index=0, margin=1.0):
    model.eval()
    correct, total = 0, 0
    with torch.no_grad():
        for img1, img2, label in dataloader:
            img1, img2, label = img1.to(device), img2.to(device), label.to(device)
            emb1 = model(img1)
            emb2 = model(img2)
            dist = torch.nn.functional.pairwise_distance(emb1, emb2)
            preds = (dist < margin).float()
            correct += (preds == (label == 0).float()).sum().item()
            total += label.size(0)
    acc = correct / total

    img1, img2, label = dataset[index]
    with torch.no_grad():
        emb1 = model(img1.unsqueeze(0).to(device))
        emb2 = model(img2.unsqueeze(0).to(device))
        dist = torch.nn.functional.pairwise_distance(emb1, emb2).item()
    is_same = dist < margin
    sim = 1 - dist
    return acc, (img1, img2), sim, is_same


def evaluate_triplet(model, dataset, dataloader, index=0, margin=1.0):
    # Same evaluation logic as contrastive
    return evaluate_contrastive(model, dataset, dataloader, index, margin)


# Run all three evaluations
bce_acc, bce_imgs, bce_sim, bce_same = evaluate_bce(bce_model, test_dataset, test_loader, index=30)
contrastive_acc, contrastive_imgs, contrastive_sim, contrastive_same = evaluate_contrastive(contrastive_net, test_dataset, test_loader, index=30)
triplet_acc, triplet_imgs, triplet_sim, triplet_same = evaluate_triplet(triplet_net, test_dataset, test_loader, index=30)

# Print side-by-side summary
print(f"{'Model':<15}{'Accuracy':<15}{'Similarity':<15}{'Decision':<10}")
print(f"{'-'*55}")
print(f"{'BCE':<15}{bce_acc*100:>7.2f}%{'':<8}{bce_sim:>10.2f}{'':<5}{'Same' if bce_same else 'Different'}")
print(f"{'Contrastive':<15}{contrastive_acc*100:>7.2f}%{'':<8}{contrastive_sim:>10.2f}{'':<5}{'Same' if contrastive_same else 'Different'}")
print(f"{'Triplet':<15}{triplet_acc*100:>7.2f}%{'':<8}{triplet_sim:>10.2f}{'':<5}{'Same' if triplet_same else 'Different'}")

# Show side-by-side image verification
show_verification_row(
    images=[bce_imgs, contrastive_imgs, triplet_imgs],
    sims=[bce_sim, contrastive_sim, triplet_sim],
    decisions=[bce_same, contrastive_same, triplet_same],
    titles=["BCE", "Contrastive", "Triplet"]
)
# Out:
# Model          Accuracy       Similarity     Decision
# -------------------------------------------------------
# BCE              53.10%              0.72     Same
# Contrastive      49.60%              0.91     Same
# Triplet          47.30%              0.79     Same
