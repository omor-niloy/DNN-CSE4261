# %%
# %pip install torchmetrics

# %%
import os
import random
import torch
import numpy as np
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader, random_split, Subset
import torch.nn as nn
import torch.nn.functional as F
from torchmetrics.classification import MulticlassAccuracy
import torch.optim as optim
from tqdm import tqdm
import time

# %% [markdown]
# # Dataset

# %%
# Load dataset
seed = 42
torch.manual_seed(seed)
random.seed(seed)
np.random.seed(seed)
val_ratio = 0.1
generator = torch.Generator().manual_seed(seed)
use_reduced_data = True

transform = transforms.Compose([
    transforms.RandomResizedCrop((32, 32), scale=(0.8, 1.0)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation((-30, 30)),
    # transforms.ColorJitter(),
    transforms.RandAugment(num_ops=2, magnitude=7),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

transformTest = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

CIFAR10Dataset = torchvision.datasets.CIFAR10(root='.', download=True)
full_train_dataset = torchvision.datasets.CIFAR10(root='.', train=True, download=True, transform=None)
test_dataset = torchvision.datasets.CIFAR10(root='.', train=False, download=True, transform=transformTest)

if use_reduced_data:
    total_reduced_size = 10000
    selected_indices = torch.randperm(len(full_train_dataset), generator=generator)[:total_reduced_size]
else:
    selected_indices = torch.arange(len(full_train_dataset))

val_size = int(len(selected_indices) * val_ratio)
train_size = len(selected_indices) - val_size
train_indices, val_indices = random_split(selected_indices, [train_size, val_size], generator=generator)


train_dataset = Subset(
    torchvision.datasets.CIFAR10(root='.', train=True, download=False, transform=transform),
    train_indices.indices
)

val_dataset = Subset(
    torchvision.datasets.CIFAR10(root='.', train=True, download=False, transform=transformTest),
    val_indices.indices
)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True, num_workers=os.cpu_count())
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False, num_workers=os.cpu_count())
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False, num_workers=os.cpu_count())

# %% [markdown]
# # Small CNN model

# %%
class SmallCNN(nn.Module):
    def __init__(self, num_classes=10):
        super(SmallCNN, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )

        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(8*8*64, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(512, 256),
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.Linear(256, num_classes)
        )

    def forward(self, x):
        x = self.features(x)
        return self.classifier(x)

# %%
# !pip install torchinfo
from torchinfo import summary
# Out:
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0

# %%
summary(model, input_size=(64, 3, 32, 32))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# SmallCNN                                 [64, 10]                  --
# ├─Sequential: 1-1                        [64, 64, 8, 8]            --
# │    └─Conv2d: 2-1                       [64, 32, 32, 32]          896
# │    └─BatchNorm2d: 2-2                  [64, 32, 32, 32]          64
# │    └─ReLU: 2-3                         [64, 32, 32, 32]          --
# │    └─MaxPool2d: 2-4                    [64, 32, 16, 16]          --
# │    └─Conv2d: 2-5                       [64, 64, 16, 16]          18,496
# │    └─BatchNorm2d: 2-6                  [64, 64, 16, 16]          128
# │    └─ReLU: 2-7                         [64, 64, 16, 16]          --
# │    └─MaxPool2d: 2-8                    [64, 64, 8, 8]            --
# ├─Sequential: 1-2                        [64, 10]                  --
# │    └─Flatten: 2-9                      [64, 4096]                --
# │    └─Linear: 2-10                      [64, 512]                 2,097,664
# │    └─BatchNorm1d: 2-11                 [64, 512]                 1,024
# │    └─ReLU: 2-12                        [64, 512]                 --
# │    └─Dropout: 2-13                     [64, 512]                 --
# │    └─Linear: 2-14                      [64, 256]                 131,328
# │    └─BatchNorm1d: 2-15                 [64, 256]                 512
# │    └─ReLU: 2-16                        [64, 256]                 --
# │    └─Linear: 2-17                      [64, 10]                  2,570
# ==========================================================================================
# Total params: 2,252,682
# Trainable params: 2,252,682
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 504.69
# ==========================================================================================
# Input size (MB): 0.79
# Forward/backward pass size (MB): 51.12
# Params size (MB): 9.01
# Estimated Total Size (MB): 60.92
# ==========================================================================================

# %% [markdown]
# # Train and Validation

# %%
def train(model, train_loader, val_loader, epochs, learning_rate, device):
    criterion = nn.CrossEntropyLoss(label_smoothing=0.1)
    optimizer = optim.AdamW(model.parameters(), lr=learning_rate)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs)
    model.to(device)
    results = []
    for epoch in range(epochs):
        model.train()
        running_loss, correct, total = 0.0, 0, 0
        start_time = time.time()

        for inputs, labels in (train_loader):
            inputs, labels = inputs.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            correct += (predicted == labels).sum().item()
            total += labels.size(0)

        train_loss = running_loss / len(train_loader)
        train_acc = correct / total

        val_acc, val_loss = validation(model, val_loader, device, show_metrics=False)
        scheduler.step()
        # print(f'Learning Rate: {scheduler.get_last_lr()[-1]:0.4e}')
        print(f"Epoch {epoch+1}/{epochs}({time.time() - start_time:.2f}s)  - accuracy: {train_acc:.4f}  - loss: {train_loss:.4f}  - val_accuracy: {val_acc:.4f}  - val_loss: {val_loss:.4f}")
        results.append([train_acc, train_loss, val_acc, val_loss])
    return results

def validation(model, test_loader, device, show_metrics=True):
    metric = MulticlassAccuracy(num_classes=10).to(device)
    model.eval()
    model.to(device)

    criterion = nn.CrossEntropyLoss(label_smoothing=0.1)
    total_loss = 0.0

    with torch.no_grad():
        for inputs, labels in (test_loader):
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            metric.update(outputs, labels)
            total_loss += loss.item()

    accuracy_val = metric.compute().item()
    avg_loss = total_loss / len(test_loader)

    if show_metrics:
        print(f"Validation Accuracy: {accuracy_val:.4f} Loss: {avg_loss:.4f}")
    return accuracy_val, avg_loss

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
epochs = 50
learning_rate = 1e-3
model = SmallCNN().to(device)

history = train(model, train_loader, val_loader, epochs, learning_rate, device)
# Out:
# Epoch 1/50(14.01s)  - accuracy: 0.3204  - loss: 1.9536  - val_accuracy: 0.4729  - val_loss: 1.6414
# Epoch 2/50(7.38s)  - accuracy: 0.4002  - loss: 1.7874  - val_accuracy: 0.5131  - val_loss: 1.5579
# Epoch 3/50(8.40s)  - accuracy: 0.4447  - loss: 1.7054  - val_accuracy: 0.5267  - val_loss: 1.5262
# Epoch 4/50(8.66s)  - accuracy: 0.4738  - loss: 1.6495  - val_accuracy: 0.5203  - val_loss: 1.5601
# Epoch 5/50(7.38s)  - accuracy: 0.4891  - loss: 1.6277  - val_accuracy: 0.5582  - val_loss: 1.4767
# Epoch 6/50(8.40s)  - accuracy: 0.5039  - loss: 1.5959  - val_accuracy: 0.5811  - val_loss: 1.4199
# Epoch 7/50(7.81s)  - accuracy: 0.5129  - loss: 1.5681  - val_accuracy: 0.6185  - val_loss: 1.3694
# Epoch 8/50(8.04s)  - accuracy: 0.5272  - loss: 1.5340  - val_accuracy: 0.6100  - val_loss: 1.3835
# Epoch 9/50(9.30s)  - accuracy: 0.5373  - loss: 1.5186  - val_accuracy: 0.6007  - val_loss: 1.3604
# Epoch 10/50(7.78s)  - accuracy: 0.5531  - loss: 1.4993  - val_accuracy: 0.6292  - val_loss: 1.3329
# Epoch 11/50(8.02s)  - accuracy: 0.5469  - loss: 1.4816  - val_accuracy: 0.6311  - val_loss: 1.3286
# Epoch 12/50(8.57s)  - accuracy: 0.5549  - loss: 1.4760  - val_accuracy: 0.6110  - val_loss: 1.3165
# Epoch 13/50(7.43s)  - accuracy: 0.5699  - loss: 1.4444  - val_accuracy: 0.6294  - val_loss: 1.2852
# Epoch 14/50(8.57s)  - accuracy: 0.5731  - loss: 1.4374  - val_accuracy: 0.6421  - val_loss: 1.2916
# Epoch 15/50(8.53s)  - accuracy: 0.5766  - loss: 1.4217  - val_accuracy: 0.6602  - val_loss: 1.2582
# Epoch 16/50(7.48s)  - accuracy: 0.5887  - loss: 1.4124  - val_accuracy: 0.6495  - val_loss: 1.2740
# Epoch 17/50(8.57s)  - accuracy: 0.6038  - loss: 1.3980  - val_accuracy: 0.6763  - val_loss: 1.2380
# Epoch 18/50(8.64s)  - accuracy: 0.5988  - loss: 1.3856  - val_accuracy: 0.6666  - val_loss: 1.2390
# Epoch 19/50(7.57s)  - accuracy: 0.6044  - loss: 1.3738  - val_accuracy: 0.6621  - val_loss: 1.2432
# Epoch 20/50(8.51s)  - accuracy: 0.6124  - loss: 1.3681  - val_accuracy: 0.6846  - val_loss: 1.2060
# Epoch 21/50(8.10s)  - accuracy: 0.6188  - loss: 1.3481  - val_accuracy: 0.6797  - val_loss: 1.2506
# Epoch 22/50(7.99s)  - accuracy: 0.6244  - loss: 1.3369  - val_accuracy: 0.6787  - val_loss: 1.2106
# Epoch 23/50(8.80s)  - accuracy: 0.6293  - loss: 1.3321  - val_accuracy: 0.6777  - val_loss: 1.1934
# Epoch 24/50(8.02s)  - accuracy: 0.6372  - loss: 1.3114  - val_accuracy: 0.6803  - val_loss: 1.2001
# Epoch 25/50(8.11s)  - accuracy: 0.6437  - loss: 1.2938  - val_accuracy: 0.6848  - val_loss: 1.2138
# Epoch 26/50(8.49s)  - accuracy: 0.6441  - loss: 1.2975  - val_accuracy: 0.6989  - val_loss: 1.1772
# Epoch 27/50(7.75s)  - accuracy: 0.6478  - loss: 1.2832  - val_accuracy: 0.7134  - val_loss: 1.1681
# Epoch 28/50(8.30s)  - accuracy: 0.6536  - loss: 1.2816  - val_accuracy: 0.6775  - val_loss: 1.2121
# Epoch 29/50(8.68s)  - accuracy: 0.6554  - loss: 1.2749  - val_accuracy: 0.6998  - val_loss: 1.1713
# Epoch 30/50(7.63s)  - accuracy: 0.6637  - loss: 1.2658  - val_accuracy: 0.6917  - val_loss: 1.1719
# Epoch 31/50(8.46s)  - accuracy: 0.6749  - loss: 1.2445  - val_accuracy: 0.6958  - val_loss: 1.1933
# Epoch 32/50(8.63s)  - accuracy: 0.6709  - loss: 1.2428  - val_accuracy: 0.7061  - val_loss: 1.1673
# Epoch 33/50(7.55s)  - accuracy: 0.6717  - loss: 1.2470  - val_accuracy: 0.7095  - val_loss: 1.1506
# Epoch 34/50(8.67s)  - accuracy: 0.6753  - loss: 1.2286  - val_accuracy: 0.7083  - val_loss: 1.1661
# Epoch 35/50(8.48s)  - accuracy: 0.6801  - loss: 1.2307  - val_accuracy: 0.7181  - val_loss: 1.1500
# Epoch 36/50(7.49s)  - accuracy: 0.6812  - loss: 1.2264  - val_accuracy: 0.7137  - val_loss: 1.1321
# Epoch 37/50(8.57s)  - accuracy: 0.7001  - loss: 1.2058  - val_accuracy: 0.7135  - val_loss: 1.1381
# Epoch 38/50(8.01s)  - accuracy: 0.7051  - loss: 1.1931  - val_accuracy: 0.7356  - val_loss: 1.1250
# Epoch 39/50(7.87s)  - accuracy: 0.6923  - loss: 1.2010  - val_accuracy: 0.7297  - val_loss: 1.1203
# Epoch 40/50(8.52s)  - accuracy: 0.6993  - loss: 1.1999  - val_accuracy: 0.7242  - val_loss: 1.1325
# Epoch 41/50(7.57s)  - accuracy: 0.6967  - loss: 1.1988  - val_accuracy: 0.7276  - val_loss: 1.1262
# Epoch 42/50(8.48s)  - accuracy: 0.6998  - loss: 1.1871  - val_accuracy: 0.7299  - val_loss: 1.1289
# Epoch 43/50(8.40s)  - accuracy: 0.6964  - loss: 1.1941  - val_accuracy: 0.7243  - val_loss: 1.1309
# Epoch 44/50(7.42s)  - accuracy: 0.7039  - loss: 1.1848  - val_accuracy: 0.7270  - val_loss: 1.1229
# Epoch 45/50(8.54s)  - accuracy: 0.6993  - loss: 1.1834  - val_accuracy: 0.7237  - val_loss: 1.1307
# Epoch 46/50(8.48s)  - accuracy: 0.7032  - loss: 1.1858  - val_accuracy: 0.7250  - val_loss: 1.1257
# Epoch 47/50(7.37s)  - accuracy: 0.7070  - loss: 1.1699  - val_accuracy: 0.7283  - val_loss: 1.1288
# Epoch 48/50(8.57s)  - accuracy: 0.7096  - loss: 1.1737  - val_accuracy: 0.7273  - val_loss: 1.1255
# Epoch 49/50(8.30s)  - accuracy: 0.6974  - loss: 1.1835  - val_accuracy: 0.7247  - val_loss: 1.1311
# Epoch 50/50(8.00s)  - accuracy: 0.7036  - loss: 1.1798  - val_accuracy: 0.7269  - val_loss: 1.1241

# %%
validation(model, test_loader, device)
# Out:
# Validation Accuracy: 0.7183 Loss: 1.1520
# (0.7182999849319458, 1.151978678004757)

# %%
import matplotlib.pyplot as plt

# Unpack the history
train_acc = [row[0] for row in history]
train_loss = [row[1] for row in history]
val_acc   = [row[2] for row in history]
val_loss  = [row[3] for row in history]
epochs = range(1, len(history) + 1)

# Plotting
plt.figure(figsize=(12, 5))

# Subplot 1: Accuracy
plt.subplot(1, 2, 1)
plt.plot(epochs, train_acc, label='Train Accuracy')
plt.plot(epochs, val_acc, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy over Epochs')
plt.legend()
plt.grid(True)

# Subplot 2: Loss
plt.subplot(1, 2, 2)
plt.plot(epochs, train_loss, label='Train Loss')
plt.plot(epochs, val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss over Epochs')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
