# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from torchvision.utils import make_grid
import matplotlib.pyplot as plt
from PIL import Image
import pandas as pd
import os
import numpy as np

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

IMAGE_SIZE = 64
BATCH_SIZE = 64
LATENT_DIM = 100
NUM_EPOCHS = 150
LR = 2e-4
workers = 2
ADAM_BETA_1 = 0.5


NUM_CLASSES = 2  # Long Hair / Not Long Hair
IMG_CHANNELS = 3
IMG_SHAPE = (IMG_CHANNELS, IMAGE_SIZE, IMAGE_SIZE)

# %%
import os
import pandas as pd
from torch.utils.data import Dataset
from PIL import Image

class LongHairCelebADataset(Dataset):
    def __init__(self, img_dir, attr_file, transform=None):
        self.img_dir = img_dir
        self.transform = transform
        
        # Load CSV with proper delimiter
        self.attrs = pd.read_csv(attr_file)  # <-- Updated from read_table
        self.image_names = self.attrs['image_id'].tolist()

        # Label: 1 for long hair (not male and not bald), 0 otherwise
        self.labels = []
        for _, row in self.attrs.iterrows():
            is_male = row['Male'] == 1
            is_bald = row['Bald'] == 1
            label = 1 if not is_male and not is_bald else 0
            self.labels.append(label)

    def __len__(self):
        return len(self.image_names)

    def __getitem__(self, idx):
        img_name = self.image_names[idx]
        img_path = os.path.join(self.img_dir, img_name)
        image = Image.open(img_path).convert("RGB")
        
        if self.transform:
            image = self.transform(image)

        label = self.labels[idx]
        return image, label

# %%
DATA_DIR = '/home/cse/Documents/NP/datasets/CelebA'
img_dir_path = os.path.join(DATA_DIR, 'img_align_celeba/img_align_celeba')
attr_file_path = os.path.join(DATA_DIR, 'list_attr_celeba.csv')

IMAGE_SIZE = 64
BATCH_SIZE = 16
workers = 2

transformations = transforms.Compose([
    transforms.Resize(IMAGE_SIZE),
    transforms.CenterCrop(IMAGE_SIZE),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

full_dataset = LongHairCelebADataset(img_dir=img_dir_path, attr_file=attr_file_path, transform=transformations)
subset_indices = list(range(5000))
celeba_dataset = torch.utils.data.Subset(full_dataset, subset_indices)
dataloader = torch.utils.data.DataLoader(celeba_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=workers)

labels_np = np.array([full_dataset.labels[i] for i in subset_indices])
print(f"Subset loaded: {len(celeba_dataset)} images")
print(f"Long hair: {np.sum(labels_np == 1)}")
print(f"Not long hair: {np.sum(labels_np == 0)}")
# Out:
# Subset loaded: 5000 images
# Long hair: 2917
# Not long hair: 2083

# %%
class Generator(nn.Module):
    def __init__(self, latent_dim, num_classes, img_shape):
        super(Generator, self).__init__()
        self.label_emb = nn.Embedding(num_classes, latent_dim)
        self.img_shape = img_shape
        input_dim = latent_dim * 2

        self.model = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.BatchNorm1d(128),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Linear(128, 256),
            nn.BatchNorm1d(256),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Linear(256, 512),
            nn.BatchNorm1d(512),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Linear(512, int(np.prod(img_shape))),
            nn.Tanh()
        )

    def forward(self, z, labels):
        label_embed = self.label_emb(labels.long())
        x = torch.cat((z, label_embed), dim=1)
        img = self.model(x)
        img = img.view(img.size(0), *self.img_shape)
        return img

# %%
class Discriminator(nn.Module):
    def __init__(self, num_classes, img_shape):
        super(Discriminator, self).__init__()
        self.img_shape = img_shape
        self.label_emb = nn.Embedding(num_classes, int(np.prod(img_shape)))

        self.model = nn.Sequential(
            nn.Linear(int(np.prod(img_shape)) * 2, 512),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Linear(512, 256),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Linear(256, 1),
            nn.Sigmoid()
        )

    def forward(self, img, labels):
        img_flat = img.view(img.size(0), -1)
        label_embed = self.label_emb(labels.long())
        d_in = torch.cat((img_flat, label_embed), dim=1)
        validity = self.model(d_in)
        return validity

# %%
G = Generator(latent_dim=LATENT_DIM, num_classes=NUM_CLASSES, img_shape=IMG_SHAPE).to(device)
D = Discriminator(num_classes=NUM_CLASSES, img_shape=IMG_SHAPE).to(device)

criterion = nn.BCELoss()
optimizer_G = optim.Adam(G.parameters(), lr=LR, betas=(0.5, 0.999))
optimizer_D = optim.Adam(D.parameters(), lr=LR, betas=(0.5, 0.999))

# %%
def train_cgan(dataloader, epochs):
    G_losses, D_losses = [], []

    for epoch in range(epochs):
        for imgs, labels in dataloader:
            batch_size = imgs.size(0)
            valid = torch.ones(batch_size, 1).to(device)
            fake = torch.zeros(batch_size, 1).to(device)
            real_imgs = imgs.to(device)
            labels = labels.long().to(device)

            # -----------------
            #  Train Generator
            # -----------------
            optimizer_G.zero_grad()
            z = torch.randn(batch_size, LATENT_DIM).to(device)
            gen_imgs = G(z, labels)
            g_loss = criterion(D(gen_imgs, labels), valid)
            g_loss.backward()
            optimizer_G.step()

            # ---------------------
            #  Train Discriminator
            # ---------------------
            optimizer_D.zero_grad()
            real_loss = criterion(D(real_imgs, labels), valid)
            fake_loss = criterion(D(gen_imgs.detach(), labels), fake)
            d_loss = (real_loss + fake_loss) / 2
            d_loss.backward()
            optimizer_D.step()

        G_losses.append(g_loss.item())
        D_losses.append(d_loss.item())
        print(f"Epoch [{epoch+1}/{epochs}]  Loss_D: {d_loss.item():.4f}  Loss_G: {g_loss.item():.4f}")

    return G_losses, D_losses


if __name__ == '__main__':
    G_losses, D_losses = train_cgan(dataloader, NUM_EPOCHS)
    torch.save(G.state_dict(), 'cgan_generator.pth')
    torch.save(D.state_dict(), 'cgan_discriminator.pth')
# Out:
# Epoch [1/150]  Loss_D: 0.4812  Loss_G: 2.2424
# Epoch [2/150]  Loss_D: 1.0545  Loss_G: 1.8677
# Epoch [3/150]  Loss_D: 0.6885  Loss_G: 0.5690
# Epoch [4/150]  Loss_D: 0.7878  Loss_G: 0.3258
# Epoch [5/150]  Loss_D: 0.6229  Loss_G: 1.2864
# Epoch [6/150]  Loss_D: 0.4287  Loss_G: 1.4243
# Epoch [7/150]  Loss_D: 0.4200  Loss_G: 1.5619
# Epoch [8/150]  Loss_D: 0.6447  Loss_G: 1.0467
# Epoch [9/150]  Loss_D: 0.5943  Loss_G: 1.2720
# Epoch [10/150]  Loss_D: 0.8018  Loss_G: 0.5061
# Epoch [11/150]  Loss_D: 0.6437  Loss_G: 0.8685
# Epoch [12/150]  Loss_D: 0.4796  Loss_G: 1.0742
# Epoch [13/150]  Loss_D: 0.5259  Loss_G: 1.1064
# Epoch [14/150]  Loss_D: 0.4658  Loss_G: 1.1343
# Epoch [15/150]  Loss_D: 0.7347  Loss_G: 0.6242
# Epoch [16/150]  Loss_D: 0.7339  Loss_G: 0.7079
# Epoch [17/150]  Loss_D: 0.6272  Loss_G: 0.9997
# Epoch [18/150]  Loss_D: 0.6179  Loss_G: 1.1510
# Epoch [19/150]  Loss_D: 0.5730  Loss_G: 0.9454
# Epoch [20/150]  Loss_D: 0.6727  Loss_G: 0.5423
# Epoch [21/150]  Loss_D: 0.6082  Loss_G: 0.6246
# Epoch [22/150]  Loss_D: 0.6418  Loss_G: 0.8138
# Epoch [23/150]  Loss_D: 0.7495  Loss_G: 0.9427
# Epoch [24/150]  Loss_D: 0.6564  Loss_G: 0.8138
# Epoch [25/150]  Loss_D: 0.5504  Loss_G: 0.9448
# Epoch [26/150]  Loss_D: 0.7028  Loss_G: 1.2678
# Epoch [27/150]  Loss_D: 0.7294  Loss_G: 0.8377
# Epoch [28/150]  Loss_D: 0.5925  Loss_G: 0.9556
# Epoch [29/150]  Loss_D: 0.6379  Loss_G: 0.8446
# Epoch [30/150]  Loss_D: 0.6653  Loss_G: 1.1375
# Epoch [31/150]  Loss_D: 0.5876  Loss_G: 0.9098
# Epoch [32/150]  Loss_D: 0.6311  Loss_G: 0.8649
# Epoch [33/150]  Loss_D: 0.6015  Loss_G: 1.0687
# Epoch [34/150]  Loss_D: 0.8073  Loss_G: 0.9193
# Epoch [35/150]  Loss_D: 0.6163  Loss_G: 0.8083
# Epoch [36/150]  Loss_D: 0.5597  Loss_G: 1.1049
# Epoch [37/150]  Loss_D: 0.6664  Loss_G: 0.7520
# Epoch [38/150]  Loss_D: 0.6594  Loss_G: 1.0470
# Epoch [39/150]  Loss_D: 0.6206  Loss_G: 0.9054
# Epoch [40/150]  Loss_D: 0.6447  Loss_G: 0.7061
# Epoch [41/150]  Loss_D: 0.6280  Loss_G: 0.9406
# Epoch [42/150]  Loss_D: 0.6144  Loss_G: 1.0225
# Epoch [43/150]  Loss_D: 0.6195  Loss_G: 0.9702
# Epoch [44/150]  Loss_D: 0.6127  Loss_G: 0.7499
# Epoch [45/150]  Loss_D: 0.4198  Loss_G: 1.0339
# Epoch [46/150]  Loss_D: 0.5117  Loss_G: 0.9916
# Epoch [47/150]  Loss_D: 0.7453  Loss_G: 1.3598
# Epoch [48/150]  Loss_D: 0.5799  Loss_G: 1.0297
# Epoch [49/150]  Loss_D: 0.5925  Loss_G: 0.8644
# Epoch [50/150]  Loss_D: 0.4759  Loss_G: 1.2067
# Epoch [51/150]  Loss_D: 0.4386  Loss_G: 1.3417
# Epoch [52/150]  Loss_D: 0.5411  Loss_G: 1.4166
# Epoch [53/150]  Loss_D: 0.4357  Loss_G: 1.8557
# Epoch [54/150]  Loss_D: 0.3516  Loss_G: 1.7130
# Epoch [55/150]  Loss_D: 0.4340  Loss_G: 0.9142
# Epoch [56/150]  Loss_D: 0.7662  Loss_G: 0.6498
# Epoch [57/150]  Loss_D: 0.3401  Loss_G: 1.5069
# Epoch [58/150]  Loss_D: 0.4034  Loss_G: 1.0379
# Epoch [59/150]  Loss_D: 0.4133  Loss_G: 1.8427
# Epoch [60/150]  Loss_D: 0.3987  Loss_G: 2.0636
# Epoch [61/150]  Loss_D: 0.2312  Loss_G: 2.8881
# Epoch [62/150]  Loss_D: 0.4099  Loss_G: 1.6839
# Epoch [63/150]  Loss_D: 0.3856  Loss_G: 1.6918
# Epoch [64/150]  Loss_D: 0.1865  Loss_G: 2.0907
# Epoch [65/150]  Loss_D: 0.5005  Loss_G: 2.5495
# Epoch [66/150]  Loss_D: 0.4243  Loss_G: 1.1237
# Epoch [67/150]  Loss_D: 0.5334  Loss_G: 2.5255
# Epoch [68/150]  Loss_D: 0.3235  Loss_G: 2.1565
# Epoch [69/150]  Loss_D: 0.3881  Loss_G: 1.5371
# Epoch [70/150]  Loss_D: 0.4612  Loss_G: 0.7708
# Epoch [71/150]  Loss_D: 0.3645  Loss_G: 2.8781
# Epoch [72/150]  Loss_D: 0.4426  Loss_G: 2.0642
# Epoch [73/150]  Loss_D: 0.3770  Loss_G: 2.4288
# Epoch [74/150]  Loss_D: 0.2400  Loss_G: 2.7753
# Epoch [75/150]  Loss_D: 0.6040  Loss_G: 2.6443
# Epoch [76/150]  Loss_D: 0.1698  Loss_G: 2.3021
# Epoch [77/150]  Loss_D: 0.2180  Loss_G: 1.8875
# Epoch [78/150]  Loss_D: 0.6133  Loss_G: 2.7603
# Epoch [79/150]  Loss_D: 0.2165  Loss_G: 2.2254
# Epoch [80/150]  Loss_D: 0.1959  Loss_G: 2.0692
# Epoch [81/150]  Loss_D: 0.3253  Loss_G: 3.6326
# Epoch [82/150]  Loss_D: 0.2001  Loss_G: 2.4612
# Epoch [83/150]  Loss_D: 0.2200  Loss_G: 3.6562
# Epoch [84/150]  Loss_D: 0.3006  Loss_G: 1.5831
# Epoch [85/150]  Loss_D: 0.4273  Loss_G: 1.6568
# Epoch [86/150]  Loss_D: 0.2474  Loss_G: 1.5051
# Epoch [87/150]  Loss_D: 0.4525  Loss_G: 2.1955
# Epoch [88/150]  Loss_D: 0.3485  Loss_G: 1.6622
# Epoch [89/150]  Loss_D: 0.2462  Loss_G: 2.0827
# Epoch [90/150]  Loss_D: 0.4029  Loss_G: 1.6276
# Epoch [91/150]  Loss_D: 0.3434  Loss_G: 3.0625
# Epoch [92/150]  Loss_D: 0.2737  Loss_G: 2.7663
# Epoch [93/150]  Loss_D: 0.2051  Loss_G: 3.9601
# Epoch [94/150]  Loss_D: 0.3332  Loss_G: 2.7607
# Epoch [95/150]  Loss_D: 0.1772  Loss_G: 2.2369
# Epoch [96/150]  Loss_D: 0.5648  Loss_G: 2.0612
# Epoch [97/150]  Loss_D: 0.3124  Loss_G: 3.6030
# Epoch [98/150]  Loss_D: 0.4876  Loss_G: 2.8541
# Epoch [99/150]  Loss_D: 0.3794  Loss_G: 2.1325
# Epoch [100/150]  Loss_D: 0.2914  Loss_G: 2.0171
# Epoch [101/150]  Loss_D: 0.2947  Loss_G: 3.3324
# Epoch [102/150]  Loss_D: 0.2901  Loss_G: 2.4601
# Epoch [103/150]  Loss_D: 0.3550  Loss_G: 2.5051
# Epoch [104/150]  Loss_D: 0.1909  Loss_G: 2.5084
# Epoch [105/150]  Loss_D: 0.3237  Loss_G: 2.1363
# Epoch [106/150]  Loss_D: 0.3439  Loss_G: 3.1116
# Epoch [107/150]  Loss_D: 0.3617  Loss_G: 2.4230
# Epoch [108/150]  Loss_D: 0.2036  Loss_G: 1.5580
# Epoch [109/150]  Loss_D: 0.3347  Loss_G: 3.3529
# Epoch [110/150]  Loss_D: 0.1895  Loss_G: 2.6730
# Epoch [111/150]  Loss_D: 0.2820  Loss_G: 3.9827
# Epoch [112/150]  Loss_D: 0.1025  Loss_G: 2.9128
# Epoch [113/150]  Loss_D: 0.4247  Loss_G: 2.0388
# Epoch [114/150]  Loss_D: 0.2674  Loss_G: 3.7616
# Epoch [115/150]  Loss_D: 0.2180  Loss_G: 2.4441
# Epoch [116/150]  Loss_D: 0.2774  Loss_G: 2.5739
# Epoch [117/150]  Loss_D: 0.2146  Loss_G: 2.9138
# Epoch [118/150]  Loss_D: 0.2996  Loss_G: 3.0364
# Epoch [119/150]  Loss_D: 0.1200  Loss_G: 2.7667
# Epoch [120/150]  Loss_D: 0.2147  Loss_G: 2.8728
# Epoch [121/150]  Loss_D: 0.3103  Loss_G: 3.8469
# Epoch [122/150]  Loss_D: 0.2154  Loss_G: 1.8582
# Epoch [123/150]  Loss_D: 0.1655  Loss_G: 4.5468
# Epoch [124/150]  Loss_D: 0.4498  Loss_G: 3.0100
# Epoch [125/150]  Loss_D: 0.3549  Loss_G: 3.2743
# Epoch [126/150]  Loss_D: 0.1787  Loss_G: 3.7457
# Epoch [127/150]  Loss_D: 0.0800  Loss_G: 4.3958
# Epoch [128/150]  Loss_D: 0.0983  Loss_G: 4.3135
# Epoch [129/150]  Loss_D: 0.2364  Loss_G: 5.1650
# Epoch [130/150]  Loss_D: 0.2741  Loss_G: 3.4713
# Epoch [131/150]  Loss_D: 0.3546  Loss_G: 2.7769
# Epoch [132/150]  Loss_D: 0.2166  Loss_G: 2.8879
# Epoch [133/150]  Loss_D: 0.1959  Loss_G: 3.5176
# Epoch [134/150]  Loss_D: 0.3208  Loss_G: 3.7485
# Epoch [135/150]  Loss_D: 0.1599  Loss_G: 4.7171
# Epoch [136/150]  Loss_D: 0.2136  Loss_G: 3.4536
# Epoch [137/150]  Loss_D: 0.2439  Loss_G: 3.5605
# Epoch [138/150]  Loss_D: 0.0761  Loss_G: 3.5722
# Epoch [139/150]  Loss_D: 0.1041  Loss_G: 4.1186
# Epoch [140/150]  Loss_D: 0.1079  Loss_G: 4.1897
# Epoch [141/150]  Loss_D: 0.3173  Loss_G: 1.7028
# Epoch [142/150]  Loss_D: 0.3857  Loss_G: 3.6822
# Epoch [143/150]  Loss_D: 0.0895  Loss_G: 3.7687
# Epoch [144/150]  Loss_D: 0.1639  Loss_G: 3.1009
# Epoch [145/150]  Loss_D: 0.2416  Loss_G: 4.1082
# Epoch [146/150]  Loss_D: 0.2656  Loss_G: 4.9248
# Epoch [147/150]  Loss_D: 0.5927  Loss_G: 3.8668
# Epoch [148/150]  Loss_D: 0.4282  Loss_G: 4.9419
# Epoch [149/150]  Loss_D: 0.1589  Loss_G: 2.3081
# Epoch [150/150]  Loss_D: 0.1010  Loss_G: 3.8417

# %%
import torch
from torchvision.utils import make_grid
import matplotlib.pyplot as plt

# Set model to evaluation mode
G.eval()

# Generate noise and long-hair labels
z = torch.randn(16, LATENT_DIM).to(device)  # Random noise
labels = torch.ones(16, dtype=torch.long).to(device)  # Class label = 1 (long hair)

# Generate fake images
with torch.no_grad():
    gen_imgs = G(z, labels).cpu()

# Rescale images from [-1, 1] to [0, 1]
gen_imgs = (gen_imgs + 1) / 2

# Display image grid
grid = make_grid(gen_imgs, nrow=4)
plt.figure(figsize=(6, 6))
plt.imshow(grid.permute(1, 2, 0))
plt.axis('off')
plt.title("Generated Faces with Long Hair (Class 1)")
plt.show()

# %%
from torchvision.utils import save_image
save_image(gen_imgs, "generated_longhair_faces.png", nrow=4, normalize=True)

# %%
import matplotlib.pyplot as plt
import torch
from torchvision.utils import make_grid

# Collect 9 real images with long hair (label == 1)
real_samples = []
real_labels = []

for real_imgs, labels in dataloader:
    idx = (labels == 1).nonzero(as_tuple=True)[0]
    if len(idx) > 0:
        real_samples.append(real_imgs[idx])
        real_labels.append(labels[idx])
    if sum(x.size(0) for x in real_samples) >= 9:
        break

real_imgs = torch.cat(real_samples, dim=0)[:9].to(device)
labels = torch.cat(real_labels, dim=0)[:9].to(device)

# Generate 9 fake images with long hair
z = torch.randn(9, LATENT_DIM).to(device)
long_hair_labels = torch.ones(9, dtype=torch.long).to(device)

G.eval()
with torch.no_grad():
    fake_imgs = G(z, long_hair_labels).cpu()

# Move real images to CPU and denormalize
real_imgs = real_imgs.cpu()
real_imgs = (real_imgs + 1) / 2
fake_imgs = (fake_imgs + 1) / 2

# Create grids
real_grid = make_grid(real_imgs, nrow=3, normalize=False)
fake_grid = make_grid(fake_imgs, nrow=3, normalize=False)

# Plot side-by-side
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(real_grid.permute(1, 2, 0))
plt.axis('off')
plt.title('Real Long Hair Images')

plt.subplot(1, 2, 2)
plt.imshow(fake_grid.permute(1, 2, 0))
plt.axis('off')
plt.title('Generated Long Hair Images')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(G_losses, label="Generator Loss")
plt.plot(D_losses, label="Discriminator Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training Loss Curves")
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import torch
from torchvision.utils import make_grid

# Number of samples
N_SAMPLES = 16

# Collect real images with long hair (label == 1)
real_samples = []
real_labels = []

for real_imgs, labels in dataloader:
    idx = (labels == 1).nonzero(as_tuple=True)[0]
    if len(idx) > 0:
        real_samples.append(real_imgs[idx])
        real_labels.append(labels[idx])
    if sum(x.size(0) for x in real_samples) >= N_SAMPLES:
        break

real_imgs = torch.cat(real_samples, dim=0)[:N_SAMPLES].to(device)
labels = torch.cat(real_labels, dim=0)[:N_SAMPLES].to(device)

# Generate fake images with long hair
z = torch.randn(N_SAMPLES, LATENT_DIM).to(device)
long_hair_labels = torch.ones(N_SAMPLES, dtype=torch.long).to(device)

G.eval()
with torch.no_grad():
    fake_imgs = G(z, long_hair_labels).cpu()

# Move real images to CPU and denormalize
real_imgs = real_imgs.cpu()
real_imgs = (real_imgs + 1) / 2
fake_imgs = (fake_imgs + 1) / 2

# Create grids
real_grid = make_grid(real_imgs, nrow=4, normalize=False)
fake_grid = make_grid(fake_imgs, nrow=4, normalize=False)

# Plot side-by-side
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.imshow(real_grid.permute(1, 2, 0))
plt.axis('off')
plt.title('Real Long Hair Images')

plt.subplot(1, 2, 2)
plt.imshow(fake_grid.permute(1, 2, 0))
plt.axis('off')
plt.title('Generated Long Hair Images')

plt.tight_layout()
plt.show()
