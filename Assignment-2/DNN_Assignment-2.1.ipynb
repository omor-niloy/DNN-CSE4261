# %%
import tensorflow as tf
from tensorflow.keras import layers, models, applications, datasets
from tensorflow.keras.utils import to_categorical
import numpy as np
from tensorflow.keras.applications import Xception


(x_train, y_train), (x_test, y_test) = datasets.mnist.load_data()
x_train, y_train = x_train[:1000], y_train[:1000]
x_test, y_test = x_test[:200], y_test[:200]
x_train = np.stack([x_train]*3, axis=-1).astype("float32") / 255.0
x_test = np.stack([x_test]*3, axis=-1).astype("float32") / 255.0
def resize_batch(x):
    return tf.image.resize(x, [224, 224]).numpy()

x_train_resized = np.concatenate([resize_batch(x_train[i:i+500]) for i in range(0, len(x_train), 500)])
x_test_resized = np.concatenate([resize_batch(x_test[i:i+500]) for i in range(0, len(x_test), 500)])

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)
activations = ['relu', 'softmax', 'tanh', 'sigmoid']
base_model = Xception(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False

results = {}

for act in activations:
    model = models.Sequential([
        base_model,
        layers.GlobalAveragePooling2D(),
        layers.Dense(256, activation=act),
        layers.Dense(10, activation='softmax')
    ])

    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    history = model.fit(x_train_resized, y_train, epochs=2, batch_size=32, verbose=0,
                        validation_data=(x_test_resized, y_test))

    acc = history.history['val_accuracy'][-1]
    results[act] = acc
    print(f"Activation: {act:8s} -> Validation Accuracy: {acc:.4f}")

print("\nSummary of activation performance on Xception:")
for act, acc in results.items():
    print(f"{act:<10}: {acc:.4f}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Activation: relu     -> Validation Accuracy: 0.8300
# Activation: softmax  -> Validation Accuracy: 0.6300
# Activation: tanh     -> Validation Accuracy: 0.8450
# Activation: sigmoid  -> Validation Accuracy: 0.7800
#
# Summary of activation performance on Xception:
# relu      : 0.8300
# softmax   : 0.6300
# tanh      : 0.8450
# sigmoid   : 0.7800

# %%
from tensorflow.keras.applications import VGG16

base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False
results = {}

for act in activations:
    model = models.Sequential([
        base_model,
        layers.GlobalAveragePooling2D(),
        layers.Dense(256, activation=act),
        layers.Dense(10, activation='softmax')
    ])

    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    history = model.fit(x_train_resized, y_train, epochs=2, batch_size=32, verbose=0,
                        validation_data=(x_test_resized, y_test))

    acc = history.history['val_accuracy'][-1]
    results[act] = acc
    print(f"Activation: {act:8s} -> Validation Accuracy: {acc:.4f}")

print("\nSummary of activation performance on VGG16:")
for act, acc in results.items():
    print(f"{act:<10}: {acc:.4f}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Activation: relu     -> Validation Accuracy: 0.4700
# Activation: softmax  -> Validation Accuracy: 0.1200
# Activation: tanh     -> Validation Accuracy: 0.6800
# Activation: sigmoid  -> Validation Accuracy: 0.4550
#
# Summary of activation performance on VGG16:
# relu      : 0.4700
# softmax   : 0.1200
# tanh      : 0.6800
# sigmoid   : 0.4550

# %%
from tensorflow.keras.applications import VGG19


base_model = VGG19(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False

results = {}

for act in activations:
    model = models.Sequential([
        base_model,
        layers.GlobalAveragePooling2D(),
        layers.Dense(256, activation=act),
        layers.Dense(10, activation='softmax')
    ])

    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    history = model.fit(x_train_resized, y_train, epochs=2, batch_size=32, verbose=0,
                        validation_data=(x_test_resized, y_test))

    acc = history.history['val_accuracy'][-1]
    results[act] = acc
    print(f"Activation: {act:8s} -> Validation Accuracy: {acc:.4f}")

print("\nSummary of activation performance on VGG19:")
for act, acc in results.items():
    print(f"{act:<10}: {acc:.4f}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Activation: relu     -> Validation Accuracy: 0.6200
# Activation: softmax  -> Validation Accuracy: 0.1200
# Activation: tanh     -> Validation Accuracy: 0.7850
# Activation: sigmoid  -> Validation Accuracy: 0.3900
#
# Summary of activation performance on VGG19:
# relu      : 0.6200
# softmax   : 0.1200
# tanh      : 0.7850
# sigmoid   : 0.3900

# %%
from tensorflow.keras.applications import ResNet50

base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False
results = {}

for act in activations:
    model = models.Sequential([
        base_model,
        layers.GlobalAveragePooling2D(),
        layers.Dense(256, activation=act),
        layers.Dense(10, activation='softmax')
    ])

    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    history = model.fit(x_train_resized, y_train, epochs=2, batch_size=32, verbose=0,
                        validation_data=(x_test_resized, y_test))

    acc = history.history['val_accuracy'][-1]
    results[act] = acc
    print(f"Activation: {act:8s} -> Validation Accuracy: {acc:.4f}")

print("\nSummary of activation performance on ResNet50:")
for act, acc in results.items():
    print(f"{act:<10}: {acc:.4f}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Activation: relu     -> Validation Accuracy: 0.3150
# Activation: softmax  -> Validation Accuracy: 0.1250
# Activation: tanh     -> Validation Accuracy: 0.3450
# Activation: sigmoid  -> Validation Accuracy: 0.3350
#
# Summary of activation performance on ResNet50:
# relu      : 0.3150
# softmax   : 0.1250
# tanh      : 0.3450
# sigmoid   : 0.3350

# %%
from tensorflow.keras.applications import ResNet50V2

base_model = ResNet50V2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False
results = {}

for act in activations:
    model = models.Sequential([
        base_model,
        layers.GlobalAveragePooling2D(),
        layers.Dense(256, activation=act),
        layers.Dense(10, activation='softmax')
    ])

    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    history = model.fit(x_train_resized, y_train, epochs=2, batch_size=32, verbose=0,
                        validation_data=(x_test_resized, y_test))

    acc = history.history['val_accuracy'][-1]
    results[act] = acc
    print(f"Activation: {act:8s} -> Validation Accuracy: {acc:.4f}")

print("\nSummary of activation performance on ResNet50V2:")
for act, acc in results.items():
    print(f"{act:<10}: {acc:.4f}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94668760/94668760 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Activation: relu     -> Validation Accuracy: 0.8900
# Activation: softmax  -> Validation Accuracy: 0.5850
# Activation: tanh     -> Validation Accuracy: 0.9200
# Activation: sigmoid  -> Validation Accuracy: 0.8750
#
# Summary of activation performance on ResNet50V2:
# relu      : 0.8900
# softmax   : 0.5850
# tanh      : 0.9200
# sigmoid   : 0.8750

# %%
from tensorflow.keras.applications import ResNet101

base_model = ResNet101(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False
results = {}

for act in activations:
    model = models.Sequential([
        base_model,
        layers.GlobalAveragePooling2D(),
        layers.Dense(256, activation=act),
        layers.Dense(10, activation='softmax')
    ])

    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    history = model.fit(x_train_resized, y_train, epochs=2, batch_size=32, verbose=0,
                        validation_data=(x_test_resized, y_test))

    acc = history.history['val_accuracy'][-1]
    results[act] = acc
    print(f"Activation: {act:8s} -> Validation Accuracy: {acc:.4f}")

print("\nSummary of activation performance on ResNet101:")
for act, acc in results.items():
    print(f"{act:<10}: {acc:.4f}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171446536/171446536 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Activation: relu     -> Validation Accuracy: 0.4300
# Activation: softmax  -> Validation Accuracy: 0.1950
# Activation: tanh     -> Validation Accuracy: 0.5550
# Activation: sigmoid  -> Validation Accuracy: 0.3700
#
# Summary of activation performance on ResNet101:
# relu      : 0.4300
# softmax   : 0.1950
# tanh      : 0.5550
# sigmoid   : 0.3700

# %%
from tensorflow.keras.applications import ResNet101V2

base_model = ResNet101V2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False
results = {}

for act in activations:
    model = models.Sequential([
        base_model,
        layers.GlobalAveragePooling2D(),
        layers.Dense(256, activation=act),
        layers.Dense(10, activation='softmax')
    ])

    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    history = model.fit(x_train_resized, y_train, epochs=2, batch_size=32, verbose=0,
                        validation_data=(x_test_resized, y_test))

    acc = history.history['val_accuracy'][-1]
    results[act] = acc
    print(f"Activation: {act:8s} -> Validation Accuracy: {acc:.4f}")

print("\nSummary of activation performance on ResNet101V2:")
for act, acc in results.items():
    print(f"{act:<10}: {acc:.4f}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171317808/171317808 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Activation: relu     -> Validation Accuracy: 0.8250
# Activation: softmax  -> Validation Accuracy: 0.6550
# Activation: tanh     -> Validation Accuracy: 0.8250
# Activation: sigmoid  -> Validation Accuracy: 0.7850
#
# Summary of activation performance on ResNet101V2:
# relu      : 0.8250
# softmax   : 0.6550
# tanh      : 0.8250
# sigmoid   : 0.7850

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, applications, datasets
from tensorflow.keras.utils import to_categorical
import numpy as np
from tensorflow.keras.applications import ResNet152


(x_train, y_train), (x_test, y_test) = datasets.mnist.load_data()
x_train, y_train = x_train[:1000], y_train[:1000]
x_test, y_test = x_test[:200], y_test[:200]
x_train = np.stack([x_train]*3, axis=-1).astype("float32") / 255.0
x_test = np.stack([x_test]*3, axis=-1).astype("float32") / 255.0
def resize_batch(x):
    return tf.image.resize(x, [224, 224]).numpy()

x_train_resized = np.concatenate([resize_batch(x_train[i:i+500]) for i in range(0, len(x_train), 500)])
x_test_resized = np.concatenate([resize_batch(x_test[i:i+500]) for i in range(0, len(x_test), 500)])

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)
activations = ['relu', 'softmax', 'tanh', 'sigmoid']
base_model = ResNet152(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False

results = {}

for act in activations:
    model = models.Sequential([
        base_model,
        layers.GlobalAveragePooling2D(),
        layers.Dense(256, activation=act),
        layers.Dense(10, activation='softmax')
    ])

    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    history = model.fit(x_train_resized, y_train, epochs=2, batch_size=32, verbose=0,
                        validation_data=(x_test_resized, y_test))

    acc = history.history['val_accuracy'][-1]
    results[act] = acc
    print(f"Activation: {act:8s} -> Validation Accuracy: {acc:.4f}")

print("\nSummary of activation performance on ResNet152:")
for act, acc in results.items():
    print(f"{act:<10}: {acc:.4f}")
# Out:
# Activation: relu     -> Validation Accuracy: 0.3850
# Activation: softmax  -> Validation Accuracy: 0.2300
# Activation: tanh     -> Validation Accuracy: 0.4150
# Activation: sigmoid  -> Validation Accuracy: 0.3600
#
# Summary of activation performance on ResNet152:
# relu      : 0.3850
# softmax   : 0.2300
# tanh      : 0.4150
# sigmoid   : 0.3600

# %%
from tensorflow.keras.applications import ResNet152V2

base_model = ResNet152V2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False
results = {}

for act in activations:
    model = models.Sequential([
        base_model,
        layers.GlobalAveragePooling2D(),
        layers.Dense(256, activation=act),
        layers.Dense(10, activation='softmax')
    ])

    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    history = model.fit(x_train_resized, y_train, epochs=2, batch_size=32, verbose=0,
                        validation_data=(x_test_resized, y_test))

    acc = history.history['val_accuracy'][-1]
    results[act] = acc
    print(f"Activation: {act:8s} -> Validation Accuracy: {acc:.4f}")

print("\nSummary of activation performance on ResNet152V2:")
for act, acc in results.items():
    print(f"{act:<10}: {acc:.4f}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 234545216/234545216 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Activation: relu     -> Validation Accuracy: 0.8550
# Activation: softmax  -> Validation Accuracy: 0.5600
# Activation: tanh     -> Validation Accuracy: 0.8350
# Activation: sigmoid  -> Validation Accuracy: 0.8450
#
# Summary of activation performance on ResNet152V2:
# relu      : 0.8550
# softmax   : 0.5600
# tanh      : 0.8350
# sigmoid   : 0.8450

# %%
from tensorflow.keras.applications import MobileNet

base_model = MobileNet(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False
results = {}

for act in activations:
    model = models.Sequential([
        base_model,
        layers.GlobalAveragePooling2D(),
        layers.Dense(256, activation=act),
        layers.Dense(10, activation='softmax')
    ])

    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    history = model.fit(x_train_resized, y_train, epochs=2, batch_size=32, verbose=0,
                        validation_data=(x_test_resized, y_test))

    acc = history.history['val_accuracy'][-1]
    results[act] = acc
    print(f"Activation: {act:8s} -> Validation Accuracy: {acc:.4f}")

print("\nSummary of activation performance on MobileNet:")
for act, acc in results.items():
    print(f"{act:<10}: {acc:.4f}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17225924/17225924 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Activation: relu     -> Validation Accuracy: 0.9050
# Activation: softmax  -> Validation Accuracy: 0.7550
# Activation: tanh     -> Validation Accuracy: 0.9150
# Activation: sigmoid  -> Validation Accuracy: 0.8850
#
# Summary of activation performance on MobileNet:
# relu      : 0.9050
# softmax   : 0.7550
# tanh      : 0.9150
# sigmoid   : 0.8850
