# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.pt')
results = model.train(
    data='/home/cse/Documents/NP/datasets/WiderFace/data.yaml',
    epochs=10,
    imgsz=640,
    batch=8,
    device='cuda:0',
    )
# Out:
# Ultralytics 8.3.162 🚀 Python-3.9.22 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce GTX 1070, 8099MiB)
# ...

# %%
results = model.val(data='/home/cse/Documents/NP/datasets/WiderFace/data.yaml', split = 'val', iou=0.45)
# Out:
# Ultralytics 8.3.162 🚀 Python-3.9.22 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce GTX 1070, 8099MiB)
# Model summary (fused): 72 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3277.5±1284.9 MB/s, size: 117.2 KB)
# val: Scanning /home/cse/Documents/NP/datasets/WiderFace/WIDER Face Dataset/val/labels.cache... 3226 images, 0 backgrounds, 1 corrupt: 100%|██████████| 3226/3226 [00:00<?, ?it/s]
# val: /home/cse/Documents/NP/datasets/WiderFace/WIDER Face Dataset/val/images/21_Festival_Festival_21_604.jpg: 1 duplicate labels removed
# val: /home/cse/Documents/NP/datasets/WiderFace/WIDER Face Dataset/val/images/39_Ice_Skating_iceskiing_39_583.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.002]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 404/404 [00:19<00:00, 20.79it/s]
# ...
